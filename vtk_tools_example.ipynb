# %%
from vtk_tools.shapefunctions import sf

# %%
b = sf(72,[2,2,2])
b.node_order_hash
# Out:
# {0: 0,
#  16: 1,
#  4: 2,
#  11: 3,
#  20: 4,
#  15: 5,
#  3: 6,
#  19: 7,
#  7: 8,
#  8: 9,
#  22: 10,
#  12: 11,
#  24: 12,
#  26: 13,
#  25: 14,
#  10: 15,
#  23: 16,
#  14: 17,
#  1: 18,
#  17: 19,
#  5: 20,
#  9: 21,
#  21: 22,
#  13: 23,
#  2: 24,
#  18: 25,
#  6: 26}

# %%
b = sf(72,1)
b.node_order_hash
# Out:
# {0: 0, 4: 1, 3: 2, 7: 3, 1: 4, 5: 5, 2: 6, 6: 7}

# %%
b = sf(72,[2,1,2])
b.node_order_hash
# Out:
# {0: 0,
#  12: 1,
#  4: 2,
#  3: 3,
#  15: 4,
#  7: 5,
#  8: 6,
#  16: 7,
#  10: 8,
#  9: 9,
#  17: 10,
#  11: 11,
#  1: 12,
#  13: 13,
#  5: 14,
#  2: 15,
#  14: 16,
#  6: 17}
